# %% [markdown]
# # CLASSIFICATION PROBLEM PROJECT:

# %% [raw]
# This project aims at the classification:
# (USING LOGISTIC REGRESSION,DECISION TREE CLASSIFIER AND RANDOM FOREST CLASSIFIER:)
# *The classification goal is to predict whether the patient has 10-year risk of future coronary heart
# disease (CHD).
# *The dataset provides the patients’ information. It includes over 4,000 records and 15 attributes.
# *the data is the collection of features like:
# ['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds','prevalentStroke',
#  'prevalentHyp', 'diabetes', 'totChol', 'sysBP','diaBP', 'BMI', 'heartRate', 'glucose']
# *This data set is derived from framhimgham and Massachusets,It has been taken from kaggle platform ,
#   contributed by kaggle datasets 'dileep070'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the csv file:
df = pd.read_csv('framingham.csv')

# %%
df.head(5)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
#describing the data for analysis;
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %%
#checking for proportion of classification groups:
print(df['TenYearCHD'].count())
print(df['TenYearCHD'].sum())
# Out:
# 4238
# 644

# %% [markdown]
# # DATA PREPROCESSING:

# %%
#CHECKING FOR NULL ENTRIES:
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
#SHAPE OF THE DATA-FRAME;
df.shape
# Out:
# (4238, 16)

# %% [markdown]
# # Filling the Null entries by inputting the missing data by the Average/Mean of the Particular feature:

# %%
df['education'].fillna(np.mean(df['education']),inplace=True)
df['glucose'].fillna(np.mean(df['glucose']),inplace=True)
df['BMI'].fillna(np.mean(df['BMI']),inplace=True)
df['totChol'].fillna(np.mean(df['totChol']),inplace=True)
df['cigsPerDay'].fillna(np.mean(df['cigsPerDay']),inplace=True)
df['BPMeds'].fillna(np.mean(df['BPMeds']),inplace=True)
df['heartRate'].fillna(np.mean(df['heartRate']),inplace=True)

# %%
#rechecking for null entries:
df.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df.head(5)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
#columns name
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %% [markdown]
# # DATA VISUALISATION:

# %%
#PLOTTING THE HEAT MAP FOR VISUALISING THE CORRELATION BETWEEN OUTPUT AND FEATURES:

# %%
sns.heatmap(df.corr(),annot = True,fmt = '.2f',annot_kws={'size':5.5},center = 0.7)
plt.show()

# %%
correlation = df.corr()
print(correlation["TenYearCHD"])
# Out:
# male               0.088428
# age                0.225256
# education         -0.053384
# currentSmoker      0.019456
# cigsPerDay         0.057775
# BPMeds             0.086774
# prevalentStroke    0.061810
# prevalentHyp       0.177603
# diabetes           0.097317
# totChol            0.081624
# sysBP              0.216429
# diaBP              0.145299
# BMI                0.074680
# heartRate          0.022898
# glucose            0.120406
# TenYearCHD         1.000000
# Name: TenYearCHD, dtype: float64

# %%
#Pair plotting each features:
sns.pairplot(df)

# %%
#Analysing the realtion between currentsmoker and TenYearCHD:
sns.jointplot(x=df['currentSmoker'],y=df['TenYearCHD'])

# %%
#Analysing the realtion between cigsPerDay and TenYearCHD:
sns.lineplot(y = df['cigsPerDay'],x = df['TenYearCHD'])
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='cigsPerDay'>

# %%
#Analysing the realtion between age and TenYearCHD:
sns.lineplot(x=df['age'],y= df['TenYearCHD'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='TenYearCHD'>

# %%
#Analysing the realtion between glucose and TenYearCHD:
sns.lineplot(y=df['glucose'],x= df['TenYearCHD'])
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='glucose'>

# %%
#Analysing the realtion between currentsmoker and TenYearCHD:
sns.lineplot(x = df['currentSmoker'],y = df['TenYearCHD'])
plt.ylabel('CHd')
# Out:
# Text(0, 0.5, 'CHd')

# %%
#Analysing number of males and females who are currently smokers:
sns.countplot(x = df['currentSmoker'],hue = df['male'])
plt.xlabel('current smoker: 0/1')
# Out:
# Text(0.5, 0, 'current smoker: 0/1')

# %%
#Analysis number of males and females with 10yearchd :
sns.countplot(x = df['TenYearCHD'],hue = df['male'])
plt.xlabel('TenYearCHD: 0/1')
# Out:
# Text(0.5, 0, 'TenYearCHD: 0/1')

# %% [markdown]
# # PREPARING THE DATA FOR TRAINING AFTER VISUALISING:

# %%
#splitting data to X and Y:
X = df.drop('TenYearCHD',axis=1)
Y = df['TenYearCHD']

# %% [raw]
#  SPLITTING INTO TRAINING AND TESTING DATA:

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=0.3,shuffle = True)

# %% [markdown]
# # MODEL SELECTION AND FITTING TRAINING DATA:

# %% [markdown]
# # 1)LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %% [markdown]
# # Scaling the Data for Better performance:

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.StandardScaler().fit(xtrain)

# %%
Xscaled = scaler.transform(xtrain)

# %%
#Fitting the data:
lr.fit(Xscaled,ytrain)
# Out:
# LogisticRegression()

# %% [markdown]
# # MODEL EVALUATION AND CROSS-VALIDATION:

# %%
#USING R-SQUARE METRIC FOR MODEL EVALIUATION ON TRAINING DATA:
lr.score(Xscaled,ytrain)
# Out:
# 0.8556979096426163

# %%
k = preprocessing.StandardScaler().fit(xtest)

# %%
scaledtest = k.transform(xtest)

# %%
#USING R-SQUARE METRIC FOR MODEL EVALIUATION ON TESTING DATA:
lr.score(scaledtest,ytest)
# Out:
# 0.8561320754716981

# %% [markdown]
# # 2)DECISION TREE CLASSIFIER:

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTc = DecisionTreeClassifier(random_state = 1,max_depth = 3)

# %%
#Fitting the training data:
DTc.fit(Xscaled,ytrain)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=1)

# %%
#USING R-SQUARE METRIC FOR MODEL EVALIUATION ON TRAINING DATA:
DTc.score(Xscaled,ytrain)
# Out:
# 0.8530006743088334

# %%
#USING R-SQUARE METRIC FOR MODEL EVALIUATION ON TESTING DATA:
DTc.score(scaledtest,ytest)
# Out:
# 0.8443396226415094

# %% [markdown]
# # 3)RANDOM FORTEST CLASSIFER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFc = RandomForestClassifier(max_depth = 3,random_state = 1)

# %%
#Fitting the training data: 
RFc.fit(Xscaled,ytrain)
# Out:
# RandomForestClassifier(max_depth=3, random_state=1)

# %%
#USING R-SQUARE METRIC FOR MODEL EVALIUATION ON TRAINING DATA:
RFc.score(Xscaled,ytrain)
# Out:
# 0.8489548213081591

# %%
#USING R-SQUARE METRIC FOR MODEL EVALIUATION ON TESTING DATA:
RFc.score(scaledtest,ytest)
# Out:
# 0.85062893081761

# %% [raw]
# BY,
# PRAJWAL ASHOK SATANNAVAR
